# %%
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
geometry = {
    "xmin": -77.0036,
    "ymin": 38.8879,
    "xmax": -76.98434,
    "ymax": 38.90007,
    "spatialReference": {
        "wkid":4326
    }
    
}
geometryType = 'esriGeometryEnvelope'

# %%
import os
from collections.abc import Generator

from arcgis.geometry import Polygon, Envelope
from azure.cosmos import CosmosClient, ContainerProxy
import h3

# %%
cosmos_url = os.getenv('COSMOS_URL')
cosmos_key = os.getenv('COSMOS_KEY')
cosmos_db = os.getenv('COSMOS_DB')
cosmos_container = os.getenv('COSMOS_CONTAINER')

client = CosmosClient(url=cosmos_url, credential=cosmos_key)
db = client.get_database_client('Yelp')
container = db.get_container_client('Items')

container
# Out:
# <ContainerProxy [dbs/Yelp/colls/Items]>

# %%
h3_bndry = h3.cell_to_boundary('8828d5911dfffff')

# %%
from arcgis.geometry import Polygon

# %%
coord_lst = list((x, y) for y, x in h3_bndry)
coord_lst.append(coord_lst[0])
coord_lst.reverse()

poly = Polygon({'rings': [coord_lst], 'spatialReference': {'wkid': 4326}})

xmin = poly.envelope.xmin
xmax = poly.envelope.xmax
ymin = poly.envelope.ymin
ymax = poly.envelope.ymax

xmin, xmax, ymin, ymax
# Out:
# (-122.91406047458825,
#  -122.90102650934975,
#  47.03816624517227,
#  47.04654317996362)

# %%
def get_intersecting_bounding_coordinates(container: ContainerProxy, xmin: float, xmax: float, ymin: float, ymax: float) -> Generator[dict]:

    # create a GeoJSON bounding box for the query
    bbox = {'type': 'Polygon', 'coordinates': [[[xmin, ymin], [xmin, ymax], [xmax, ymax], [xmax, ymin], [xmin, ymin]]]}

    # since query items is a generator, piggyback on this paradigm to generate results on-demand
    for itm in container.query_items(f'SELECT * FROM c WHERE ST_INTERSECTS(c.geometry, {bbox})', enable_cross_partition_query=True):
        yield itm
        

def get_intersecting_envelope(container: ContainerProxy, envelope: Envelope) -> Generator[dict]:
    
    # wrap the function taking raw bounding coordinates to get features in envelope
    itm_gen =  get_intersecting_bounding_coordinates(container, envelope.xmin, envelope.xmax, envelope.ymin, envelope.ymax)
    
    return itm_gen

def get_intersecting_polygon(container: ContainerProxy, polygon: Polygon) -> Generator[dict]:
    
    # get the geojson representation of the polygon
    geojson_poly = polygon.__geo_interface__
    
    # ensure not multipart geometry
    if len(geojson_poly['coordinates'][0]) > 1:
        raise ValueError('Cannot process multipart polygons. Please separate into single part polygons.')
    
    # convert to polygon with coordinates as proper lists (not tuples) so it can be processed by cosmos
    geojson_poly['type'] = 'Polygon'
    geojson_poly['coordinates'] = [[list(coords) for coords in geojson_poly['coordinates'][0][0]]]
    
    # since query items is a generator, piggyback on this paradigm to generate results on-demand
    for itm in container.query_items(f'SELECT * FROM c WHERE ST_INTERSECTS(c.geometry, {geojson_poly})', enable_cross_partition_query=True):
        yield itm
        
        
list(get_intersecting_polygon(container, poly))
# Out:
# [{'id': 'EpXCy_SSO-x8BjRLc_xUcg',
#   'alias': 'the-westside-tavern-olympia',
#   'name': 'The Westside Tavern',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ms0bt1riRWKO7PR4sNAV3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-westside-tavern-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 211,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.0457916, 'longitude': -122.9243317},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1815 Harrison Ave NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1815 Harrison Ave NW', 'Olympia, WA 98502']},
#   'phone': '+13609157839',
#   'display_phone': '(360) 915-7839',
#   'distance': 791.0977089271421,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911bfffff',
#   'h3_09': '8928d5911abffff',
#   'h3_10': '8a28d5911aa7fff',
#   'h3_11': '8b28d5911aa1fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.9243317, 47.0457916]},
#   'address': '1815 Harrison Ave NW, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXaYAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXaYAAAAAAAAAA==/',
#   '_etag': '"c20300dd-0000-0700-0000-659595060000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301830},
#  {'id': 'ZztiONHrKI895SONXtfGag',
#   'alias': 'oly-taproom-olympia',
#   'name': 'Oly Taproom',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b23TEw9id7iJbbhVLvzVVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oly-taproom-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 163,
#   'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.0468184087427, 'longitude': -122.90310917791},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '312 Columbia St NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['312 Columbia St NW', 'Olympia, WA 98501']},
#   'phone': '+13605150661',
#   'display_phone': '(360) 515-0661',
#   'distance': 985.5655130517289,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59115fffff',
#   'h3_09': '8928d591153ffff',
#   'h3_10': '8a28d5911537fff',
#   'h3_11': '8b28d5911533fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.90310917791, 47.0468184087427]},
#   'address': '312 Columbia St NW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXahAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXahAAAAAAAAAA==/',
#   '_etag': '"c20309dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'qEKmPBwlpicswX4IvLEP5Q',
#   'alias': 'the-brotherhood-lounge-olympia',
#   'name': 'The Brotherhood Lounge',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sInNXmEcLe0LOuzq9kdY4g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-brotherhood-lounge-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 135,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'divebars', 'title': 'Dive Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.0454139709473,
#    'longitude': -122.902145385742},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '119 Capitol Way N',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['119 Capitol Way N', 'Olympia, WA 98501']},
#   'phone': '+13603524153',
#   'display_phone': '(360) 352-4153',
#   'distance': 999.3328305164598,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591027ffff',
#   'h3_10': '8a28d591026ffff',
#   'h3_11': '8b28d591026dfff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.902145385742, 47.0454139709473]},
#   'address': '119 Capitol Way N, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXaiAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXaiAAAAAAAAAA==/',
#   '_etag': '"c2030bdd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'jBpNd-7JqGp9bSol5ds-hw',
#   'alias': 'iron-rabbit-restaurant-and-bar-olympia',
#   'name': 'Iron Rabbit Restaurant & Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GuPHfMWMiH2a3hm9rNv-kg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/iron-rabbit-restaurant-and-bar-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 641,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.045689, 'longitude': -122.927449},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2103 Harrison Ave NW',
#    'address2': 'Ste 1',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2103 Harrison Ave NW', 'Ste 1', 'Olympia, WA 98502']},
#   'phone': '+13609563661',
#   'display_phone': '(360) 956-3661',
#   'distance': 1007.0067648867362,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911bfffff',
#   'h3_09': '8928d5911a3ffff',
#   'h3_10': '8a28d5911a0ffff',
#   'h3_11': '8b28d5911a1dfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.927449, 47.045689]},
#   'address': '2103 Harrison Ave NW, Ste 1, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXajAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXajAAAAAAAAAA==/',
#   '_etag': '"c2030cdd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'hkTnpSYCACbUzgya4LiwZg',
#   'alias': 'dockside-bistro-and-wine-bar-olympia',
#   'name': 'Dockside Bistro & Wine Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KXIaEwfyPdj7WaBwREirCg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dockside-bistro-and-wine-bar-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 300,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.048308, 'longitude': -122.90398},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '501 Columbia St NW',
#    'address2': None,
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['501 Columbia St NW', 'Olympia, WA 98501']},
#   'phone': '+13609561928',
#   'display_phone': '(360) 956-1928',
#   'distance': 1015.6279668490508,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59115fffff',
#   'h3_09': '8928d591153ffff',
#   'h3_10': '8a28d591151ffff',
#   'h3_11': '8b28d5911519fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90398, 47.048308]},
#   'address': '501 Columbia St NW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXakAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXakAAAAAAAAAA==/',
#   '_etag': '"c2030ddd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'oN0jxgY7aBj_tYLgTIKcNw',
#   'alias': 'uptown-grill-olympia',
#   'name': 'Uptown Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SRK7mc61iD5hzoqa3GsjJg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/uptown-grill-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 344,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.043801, 'longitude': -122.901333},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '514 Capitol Way S',
#    'address2': None,
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['514 Capitol Way S', 'Olympia, WA 98501']},
#   'phone': '+13603380340',
#   'display_phone': '(360) 338-0340',
#   'distance': 1027.9136915315707,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591037ffff',
#   'h3_10': '8a28d591034ffff',
#   'h3_11': '8b28d5910348fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.901333, 47.043801]},
#   'address': '514 Capitol Way S, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXalAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXalAAAAAAAAAA==/',
#   '_etag': '"c2030edd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'L7_wgrbs1QcaiVIB2k8f1Q',
#   'alias': 'cove-olympia',
#   'name': 'COVE',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CWMECaepELRaYmRPXLtBJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cove-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 73,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.04678992385386,
#    'longitude': -122.902392546049},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '311 Capitol Way N',
#    'address2': '',
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['311 Capitol Way N', 'Olympia, WA 98501']},
#   'phone': '+13609159793',
#   'display_phone': '(360) 915-9793',
#   'distance': 1033.2969413690996,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59115fffff',
#   'h3_09': '8928d591153ffff',
#   'h3_10': '8a28d5911537fff',
#   'h3_11': '8b28d5911514fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.902392546049, 47.04678992385386]},
#   'address': '311 Capitol Way N, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXamAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXamAAAAAAAAAA==/',
#   '_etag': '"c2030fdd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'N_ZpAPaI-Id6hq8gLjJ90w',
#   'alias': 'skep-and-skein-olympia',
#   'name': 'Skep & Skein',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E6DXnTLkpDRwktedkObXWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/skep-and-skein-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 94,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.046395, 'longitude': -122.9279136},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2106 Harrison Ave NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2106 Harrison Ave NW', 'Olympia, WA 98502']},
#   'phone': '+13602924400',
#   'display_phone': '(360) 292-4400',
#   'distance': 1066.4138653218188,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911bfffff',
#   'h3_09': '8928d5911afffff',
#   'h3_10': '8a28d5911ae7fff',
#   'h3_11': '8b28d5911ae4fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.9279136, 47.046395]},
#   'address': '2106 Harrison Ave NW, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXanAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXanAAAAAAAAAA==/',
#   '_etag': '"c20310dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'sv-4hi5tP6egOW3thkSgdA',
#   'alias': 'spar-café-olympia-3',
#   'name': 'Spar Café',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/puYeRyeELqXSjFAcSQx48g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spar-caf%C3%A9-olympia-3?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 491,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.045047, 'longitude': -122.90095912888},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '114 4th Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['114 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13603576444',
#   'display_phone': '(360) 357-6444',
#   'distance': 1074.5165432472543,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591027ffff',
#   'h3_10': '8a28d5910267fff',
#   'h3_11': '8b28d5910261fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90095912888, 47.045047]},
#   'address': '114 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXaoAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXaoAAAAAAAAAA==/',
#   '_etag': '"c20311dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'Giql5BwKsINcMGAIl-eoTA',
#   'alias': 'dos-hermanos-mexican-kitchen-olympia',
#   'name': 'Dos Hermanos Mexican Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Uj5qCfy-4942bGWbEYxqVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dos-hermanos-mexican-kitchen-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 116,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.04639, 'longitude': -122.90149},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '222 Capitol Way N',
#    'address2': '',
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['222 Capitol Way N', 'Olympia, WA 98501']},
#   'phone': '+13603598131',
#   'display_phone': '(360) 359-8131',
#   'distance': 1075.3247604822054,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591027ffff',
#   'h3_10': '8a28d591024ffff',
#   'h3_11': '8b28d591024dfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90149, 47.04639]},
#   'address': '222 Capitol Way N, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXapAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXapAAAAAAAAAA==/',
#   '_etag': '"c20312dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'CvtgXzasxaxjR8ybB866-A',
#   'alias': 'chelsea-farms-oyster-bar-olympia',
#   'name': 'Chelsea Farms Oyster Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gEHJn0WQABCa4IJVIj4dGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chelsea-farms-oyster-bar-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 364,
#   'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.04639, 'longitude': -122.90149},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '222 Capitol Way N',
#    'address2': 'Ste 114',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['222 Capitol Way N', 'Ste 114', 'Olympia, WA 98501']},
#   'phone': '+13609157784',
#   'display_phone': '(360) 915-7784',
#   'distance': 1075.3247604822054,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591027ffff',
#   'h3_10': '8a28d591024ffff',
#   'h3_11': '8b28d591024dfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90149, 47.04639]},
#   'address': '222 Capitol Way N, Ste 114, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXaqAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXaqAAAAAAAAAA==/',
#   '_etag': '"c20313dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'LIgg0rPRlWXmDHTWTeAe5w',
#   'alias': 'locust-cider-olympia-olympia-2',
#   'name': 'Locust Cider Olympia',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hd5E1vVwwTLxo0er1y9Vnw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/locust-cider-olympia-olympia-2?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 9,
#   'categories': [{'alias': 'cideries', 'title': 'Cideries'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.04639, 'longitude': -122.90149},
#   'transactions': [],
#   'location': {'address1': '222 Capitol Way N',
#    'address2': '',
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['222 Capitol Way N', 'Olympia, WA 98501']},
#   'phone': '+13605150388',
#   'display_phone': '(360) 515-0388',
#   'distance': 1075.3247604822054,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591027ffff',
#   'h3_10': '8a28d591024ffff',
#   'h3_11': '8b28d591024dfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90149, 47.04639]},
#   'address': '222 Capitol Way N, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXarAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXarAAAAAAAAAA==/',
#   '_etag': '"c20314dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'wb1jIY9Q9IvIvaz0TOng-A',
#   'alias': 'rumors-wine-bar-olympia',
#   'name': 'Rumors Wine Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nSAHeIQszoZhPm-5XVHaFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rumors-wine-bar-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 20,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.0442477, 'longitude': -122.9001943},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '430 Washington St SE',
#    'address2': None,
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['430 Washington St SE', 'Olympia, WA 98501']},
#   'phone': '+13607059970',
#   'display_phone': '(360) 705-9970',
#   'distance': 1115.9750236080984,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591037ffff',
#   'h3_10': '8a28d591035ffff',
#   'h3_11': '8b28d5910359fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.9001943, 47.0442477]},
#   'address': '430 Washington St SE, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXasAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXasAAAAAAAAAA==/',
#   '_etag': '"c20315dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'gih8NrfJSYnzniRXU4mqeQ',
#   'alias': 'cheeky-martini-lounge-olympia',
#   'name': 'Cheeky Martini Lounge',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QL_hg7L3SL2u7uwkPTeqNg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cheeky-martini-lounge-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 35,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.044756, 'longitude': -122.900135},
#   'transactions': ['delivery'],
#   'location': {'address1': '406 Washington St. SE',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['406 Washington St. SE', 'Olympia, WA 98501']},
#   'phone': '+13607423313',
#   'display_phone': '(360) 742-3313',
#   'distance': 1130.8599321992735,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591027ffff',
#   'h3_10': '8a28d5910267fff',
#   'h3_11': '8b28d5910266fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.900135, 47.044756]},
#   'address': '406 Washington St. SE, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXatAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXatAAAAAAAAAA==/',
#   '_etag': '"c20316dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'RRushHsqapBOjzIA3zIPlA',
#   'alias': 'o-malleys-lounge-olympia',
#   'name': "O'Malley's Lounge",
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/o-malleys-lounge-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 5,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'karaoke', 'title': 'Karaoke'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.0473, 'longitude': -122.92812},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2200 Garfield Ave NW',
#    'address2': None,
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2200 Garfield Ave NW', 'Olympia, WA 98502']},
#   'phone': '+13609438807',
#   'display_phone': '(360) 943-8807',
#   'distance': 1140.6684702326477,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911bfffff',
#   'h3_09': '8928d5911afffff',
#   'h3_10': '8a28d5911aeffff',
#   'h3_11': '8b28d5911aeefff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.92812, 47.0473]},
#   'address': '2200 Garfield Ave NW, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXauAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXauAAAAAAAAAA==/',
#   '_etag': '"c20317dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'WFxdvXI1I8scsGd7m5yTLg',
#   'alias': 'the-4th-ave-tavern-olympia',
#   'name': 'The 4th Ave Tavern',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZjIw-GNCsFbG4k29vGY9vw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-4th-ave-tavern-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 50,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 47.04511758314839,
#    'longitude': -122.8999199883465},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '210 E 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['210 E 4th Ave', 'Olympia, WA 98501']},
#   'phone': '+13607861444',
#   'display_phone': '(360) 786-1444',
#   'distance': 1153.0947330569356,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591027ffff',
#   'h3_10': '8a28d5910267fff',
#   'h3_11': '8b28d5910262fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8999199883465, 47.04511758314839]},
#   'address': '210 E 4th Ave, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXavAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXavAAAAAAAAAA==/',
#   '_etag': '"c20318dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': '9sww0CBxrWNOPqlgpMooug',
#   'alias': 'anthonys-restaurant-olympia',
#   'name': "Anthony's Restaurant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AK90TAWLYVlx8Q8RQFNq9Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/anthonys-restaurant-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 320,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.050243735613, 'longitude': -122.90392718279},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '704 Columbia St NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['704 Columbia St NW', 'Olympia, WA 98501']},
#   'phone': '+13603579700',
#   'display_phone': '(360) 357-9700',
#   'distance': 1157.7237978553674,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59115fffff',
#   'h3_09': '8928d591143ffff',
#   'h3_10': '8a28d5911407fff',
#   'h3_11': '8b28d5911402fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.90392718279, 47.050243735613]},
#   'address': '704 Columbia St NW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXawAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXawAAAAAAAAAA==/',
#   '_etag': '"c20319dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'q3I2VJEKbFogzaTx3ro-jA',
#   'alias': 'valentina-s-lounge-restaurant-and-tequila-bar-olympia',
#   'name': 'Valentina’s Lounge Restaurant and Tequila Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jn88UyOgONIt8QE-9w7XPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/valentina-s-lounge-restaurant-and-tequila-bar-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 133,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.0450333, 'longitude': -122.8981941},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '325 4th Ave E',
#    'address2': None,
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['325 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13605150452',
#   'display_phone': '(360) 515-0452',
#   'distance': 1279.4584395619722,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591023ffff',
#   'h3_10': '8a28d5910277fff',
#   'h3_11': '8b28d5910276fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.8981941, 47.0450333]},
#   'address': '325 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXaxAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXaxAAAAAAAAAA==/',
#   '_etag': '"c2031add-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'sVTK41c0fU4J5rfpPUZ8hA',
#   'alias': 'mercato-ristorante-olympia-2',
#   'name': 'Mercato Ristorante',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ens42PmBUh6uwmKdYgsA3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mercato-ristorante-olympia-2?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 288,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.05027577063648,
#    'longitude': -122.90163530982932},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '111 Market St NE',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['111 Market St NE', 'Olympia, WA 98501']},
#   'phone': '+13605283663',
#   'display_phone': '(360) 528-3663',
#   'distance': 1289.27702869612,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59115fffff',
#   'h3_09': '8928d59114bffff',
#   'h3_10': '8a28d59114a7fff',
#   'h3_11': '8b28d59114a5fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.90163530982932, 47.05027577063648]},
#   'address': '111 Market St NE, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXayAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXayAAAAAAAAAA==/',
#   '_etag': '"c2031bdd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'gAKaQEcwTTKB1EpvbKpcFA',
#   'alias': 'china-clipper-cafe-olympia',
#   'name': 'China Clipper Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DrhpOETqNTfkO1XjBheCMw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-clipper-cafe-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 37,
#   'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 47.045444, 'longitude': -122.897758},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '402 4th Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['402 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13609436300',
#   'display_phone': '(360) 943-6300',
#   'distance': 1318.5013478634123,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591023ffff',
#   'h3_10': '8a28d591020ffff',
#   'h3_11': '8b28d591020dfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.897758, 47.045444]},
#   'address': '402 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXazAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXazAAAAAAAAAA==/',
#   '_etag': '"c2031cdd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'BMvk7GajniNgbW5O23EHzg',
#   'alias': 'eastside-club-tavern-olympia',
#   'name': 'Eastside Club Tavern',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2crIvxxZ7FqD7ZWyL6WYpQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/eastside-club-tavern-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 89,
#   'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.0454233503916,
#    'longitude': -122.897468917072},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '410 4th Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['410 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13603579985',
#   'display_phone': '(360) 357-9985',
#   'distance': 1341.8170518896557,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591023ffff',
#   'h3_10': '8a28d591020ffff',
#   'h3_11': '8b28d5910208fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.897468917072, 47.0454233503916]},
#   'address': '410 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa0AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa0AAAAAAAAAA==/',
#   '_etag': '"c2031ddd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'Sc2JwgUY8jXYFOADdgUwlA',
#   'alias': 'wild-man-brewing-gastropub-olympia',
#   'name': 'Wild Man Brewing Gastropub',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h60wJpWdZxhN1KfA58-buQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wild-man-brewing-gastropub-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 23,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'breweries', 'title': 'Breweries'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.04532261303619,
#    'longitude': -122.8972176968506},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '414 4th Ave E',
#    'address2': None,
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['414 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13604890734',
#   'display_phone': '(360) 489-0734',
#   'distance': 1358.2027285629356,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591023ffff',
#   'h3_10': '8a28d591020ffff',
#   'h3_11': '8b28d591020cfff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8972176968506, 47.04532261303619]},
#   'address': '414 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa1AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa1AAAAAAAAAA==/',
#   '_etag': '"c2031fdd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'v10V-PCZdHb2L-Yn1FXJOQ',
#   'alias': 'mccoys-tavern-olympia',
#   'name': "McCoy's Tavern",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0Y1a5ehLwrvlebJQCtnuVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mccoys-tavern-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 41,
#   'categories': [{'alias': 'bars', 'title': 'Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.045440566668, 'longitude': -122.89723166437},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '418 4th Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['418 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13603520696',
#   'display_phone': '(360) 352-0696',
#   'distance': 1359.8018893453138,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591023ffff',
#   'h3_10': '8a28d591020ffff',
#   'h3_11': '8b28d5910208fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.89723166437, 47.045440566668]},
#   'address': '418 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa2AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa2AAAAAAAAAA==/',
#   '_etag': '"c20320dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'fsyB-dXUFGUFCTORRnlZRg',
#   'alias': 'cryptatropa-bar-olympia',
#   'name': 'Cryptatropa Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mmlFuk-ep7rgEn3mjNCZyA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cryptatropa-bar-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 64,
#   'categories': [{'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.045022016597, 'longitude': -122.89685070285},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '421 4th Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['421 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13607543867',
#   'display_phone': '(360) 754-3867',
#   'distance': 1379.4393591502107,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591023ffff',
#   'h3_10': '8a28d5910207fff',
#   'h3_11': '8b28d5910201fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.89685070285, 47.045022016597]},
#   'address': '421 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa3AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa3AAAAAAAAAA==/',
#   '_etag': '"c20321dd-0000-0700-0000-659595070000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301831},
#  {'id': 'AY3TpBJGOGNGxttQ5jG3qw',
#   'alias': 'applebees-grill-bar-olympia',
#   'name': "Applebee's Grill + Bar",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Hj6oUAfEUlK4dz9ejlhXLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/applebees-grill-bar-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 119,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 47.040158, 'longitude': -122.933172},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2500 Capitol Mall Dr SW',
#    'address2': None,
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2500 Capitol Mall Dr SW', 'Olympia, WA 98502']},
#   'phone': '+13603528500',
#   'display_phone': '(360) 352-8500',
#   'distance': 1426.1986388291843,
#   'h3_07': '8728d5902ffffff',
#   'h3_08': '8828d59025fffff',
#   'h3_09': '8928d59027bffff',
#   'h3_10': '8a28d59027b7fff',
#   'h3_11': '8b28d59027b4fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.933172, 47.040158]},
#   'address': '2500 Capitol Mall Dr SW, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa4AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa4AAAAAAAAAA==/',
#   '_etag': '"c20322dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'OwFx99t6f8CZ3DtgriPAQA',
#   'alias': 'equal-latin-restaurant-and-bar-olympia',
#   'name': 'Equal Latin Restaurant and Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m8hQZ3g0HA7mvxV6sKqZWw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/equal-latin-restaurant-and-bar-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 117,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.04558, 'longitude': -122.89575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '520 4th Ave E',
#    'address2': '',
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['520 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13608194817',
#   'display_phone': '(360) 819-4817',
#   'distance': 1472.6512216196209,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591023ffff',
#   'h3_10': '8a28d591021ffff',
#   'h3_11': '8b28d591021cfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.89575, 47.04558]},
#   'address': '520 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa5AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa5AAAAAAAAAA==/',
#   '_etag': '"c20323dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'TlmYHQA86pIsV4B3ESUBmQ',
#   'alias': 'stack-571-burger-and-whiskey-bar-olympia-2',
#   'name': 'Stack 571 Burger & Whiskey Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oDuojINlwFVb28JaNWO7gw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/stack-571-burger-and-whiskey-bar-olympia-2?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 219,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.04255533931504,
#    'longitude': -122.93517443861596},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '625 Black Lake Blvd SW',
#    'address2': 'Ste 530',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['625 Black Lake Blvd SW',
#     'Ste 530',
#     'Olympia, WA 98502']},
#   'phone': '+13608102675',
#   'display_phone': '(360) 810-2675',
#   'distance': 1544.8847176006086,
#   'h3_07': '8728d5902ffffff',
#   'h3_08': '8828d59027fffff',
#   'h3_09': '8928d59027bffff',
#   'h3_10': '8a28d59026a7fff',
#   'h3_11': '8b28d59026a4fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.93517443861596, 47.04255533931504]},
#   'address': '625 Black Lake Blvd SW, Ste 530, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa6AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa6AAAAAAAAAA==/',
#   '_etag': '"c20324dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'yc_5Q_P45ym8tuXS9Dcgzg',
#   'alias': 'charlies-bar-and-grill-olympia-3',
#   'name': "Charlie's Bar & Grill",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MSGBVjL4LgcZ6XJas_AlAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/charlies-bar-and-grill-olympia-3?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 55,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'diners', 'title': 'Diners'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.04565, 'longitude': -122.89456},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '620 4th Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['620 4th Ave E', 'Olympia, WA 98501']},
#   'phone': '+13607868181',
#   'display_phone': '(360) 786-8181',
#   'distance': 1556.28380037982,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591023ffff',
#   'h3_10': '8a28d5910217fff',
#   'h3_11': '8b28d5910213fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.89456, 47.04565]},
#   'address': '620 4th Ave E, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa7AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa7AAAAAAAAAA==/',
#   '_etag': '"c20326dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'HdXn1ckLf9yatiaLn069VQ',
#   'alias': 'hash-olympia-5',
#   'name': 'Hash',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RqoZ3ZCsiJZTMthwumGiow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hash-olympia-5?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 436,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.04573, 'longitude': -122.92409},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1807 Harrison Ave NW',
#    'address2': '',
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1807 Harrison Ave NW', 'Olympia, WA 98502']},
#   'phone': '+13604890163',
#   'display_phone': '(360) 489-0163',
#   'distance': 773.5648281337692,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911bfffff',
#   'h3_09': '8928d5911abffff',
#   'h3_10': '8a28d5911aa7fff',
#   'h3_11': '8b28d5911aa1fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.92409, 47.04573]},
#   'address': '1807 Harrison Ave NW, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa+AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa+AAAAAAAAAA==/',
#   '_etag': '"c20329dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'TFLMoT1m_GlpKfe4Jcbqzg',
#   'alias': 'the-park-side-café-olympia',
#   'name': 'The Park Side Café',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tonHkfn5cOg56zB3fHkQ4g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-park-side-caf%C3%A9-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 72,
#   'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.0459584915647,
#    'longitude': -122.925163577431},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1909 Harrison Ave NW',
#    'address2': '',
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1909 Harrison Ave NW', 'Olympia, WA 98502']},
#   'phone': '+13603528344',
#   'display_phone': '(360) 352-8344',
#   'distance': 855.1353615493495,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911bfffff',
#   'h3_09': '8928d5911abffff',
#   'h3_10': '8a28d5911aaffff',
#   'h3_11': '8b28d5911aacfff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.925163577431, 47.0459584915647]},
#   'address': '1909 Harrison Ave NW, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXa-AAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXa-AAAAAAAAAA==/',
#   '_etag': '"c2032add-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'SbeBslqjZBKAnMMsB0OLNw',
#   'alias': 'headless-mumby-brewing-company-olympia',
#   'name': 'Headless Mumby Brewing Company',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kNzOHFqWBO_PI19-zFDNQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/headless-mumby-brewing-company-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 14,
#   'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 47.0469165, 'longitude': -122.9256951},
#   'transactions': [],
#   'location': {'address1': '232 Division St NW',
#    'address2': '',
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98502',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['232 Division St NW', 'Olympia, WA 98502']},
#   'phone': '+13607423880',
#   'display_phone': '(360) 742-3880',
#   'distance': 929.4436357141104,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911bfffff',
#   'h3_09': '8928d5911afffff',
#   'h3_10': '8a28d5911af7fff',
#   'h3_11': '8b28d5911af6fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.9256951, 47.0469165]},
#   'address': '232 Division St NW, Olympia, WA 98502',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXbBAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXbBAAAAAAAAAA==/',
#   '_etag': '"c2032cdd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'D0jKiGnkGEoajwsz7xNU7w',
#   'alias': 'the-wayside-cafe-olympia',
#   'name': 'The Wayside Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YZOqnIKjmbPAEOcPnEpsZw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-wayside-cafe-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 195,
#   'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.0439700755374, 'longitude': -122.901204},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '500 Capitol St',
#    'address2': '',
#    'address3': None,
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['500 Capitol St', 'Olympia, WA 98501']},
#   'phone': '+13603500233',
#   'display_phone': '(360) 350-0233',
#   'distance': 1036.2697732185918,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591037ffff',
#   'h3_10': '8a28d591034ffff',
#   'h3_11': '8b28d5910348fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.901204, 47.0439700755374]},
#   'address': '500 Capitol St, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXbEAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXbEAAAAAAAAAA==/',
#   '_etag': '"c2032fdd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'MMgXGRG3xccIvJ2lbEMG-Q',
#   'alias': 'gardners-restaurant-olympia',
#   'name': "Gardner's Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pG4DsKdiek3s5R3rX1wYEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gardners-restaurant-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 186,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.04726, 'longitude': -122.90258},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '111 Thurston Ave NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['111 Thurston Ave NW', 'Olympia, WA 98501']},
#   'phone': '+13607868466',
#   'display_phone': '(360) 786-8466',
#   'distance': 1038.3360063095693,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59115fffff',
#   'h3_09': '8928d591153ffff',
#   'h3_10': '8a28d5911517fff',
#   'h3_11': '8b28d5911510fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90258, 47.04726]},
#   'address': '111 Thurston Ave NW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXbFAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXbFAAAAAAAAAA==/',
#   '_etag': '"c20330dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'FE18cz0btYjXIY9E8fVVMw',
#   'alias': 'pizzeria-la-gitana-olympia-olympia',
#   'name': 'Pizzeria La Gitana- Olympia',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oA0kwtMfQz0Tn8sqoTqwow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzeria-la-gitana-olympia-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 553,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.0434723, 'longitude': -122.9012794},
#   'transactions': ['restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '518 Capitol Way S',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['518 Capitol Way S', 'Olympia, WA 98501']},
#   'phone': '+13607532929',
#   'display_phone': '(360) 753-2929',
#   'distance': 1040.655202619077,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591037ffff',
#   'h3_10': '8a28d591034ffff',
#   'h3_11': '8b28d591034dfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.9012794, 47.0434723]},
#   'address': '518 Capitol Way S, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXbGAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXbGAAAAAAAAAA==/',
#   '_etag': '"c20331dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'iXCIXdFMP8ZkKXWVqOoH1A',
#   'alias': 'budd-bay-cafe-olympia-6',
#   'name': 'Budd Bay Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rO1N8IVi3JRmQZTT4zW0iA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/budd-bay-cafe-olympia-6?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 601,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.04873169702502,
#    'longitude': -122.903859802987},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '525 Columbia St NW',
#    'address2': '',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['525 Columbia St NW', 'Olympia, WA 98501']},
#   'phone': '+13603576963',
#   'display_phone': '(360) 357-6963',
#   'distance': 1050.408016032984,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59115fffff',
#   'h3_09': '8928d591143ffff',
#   'h3_10': '8a28d5911427fff',
#   'h3_11': '8b28d5911426fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.903859802987, 47.04873169702502]},
#   'address': '525 Columbia St NW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXbHAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXbHAAAAAAAAAA==/',
#   '_etag': '"c20332dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': '9HcYlh5Zj_A5QzVsbpfppg',
#   'alias': 'el-sitio-olympia-5',
#   'name': 'El Sitio',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xm69tesNcM0KZv7uURbIxw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-sitio-olympia-5?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 127,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.04338297913398,
#    'longitude': -122.90070214857982},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '116 Legion Way SE',
#    'address2': 'Ste C',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['116 Legion Way SE', 'Ste C', 'Olympia, WA 98501']},
#   'phone': '+13607648952',
#   'display_phone': '(360) 764-8952',
#   'distance': 1068.9728341502362,
#   'h3_07': '8728d5910ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591037ffff',
#   'h3_10': '8a28d591034ffff',
#   'h3_11': '8b28d591034cfff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.90070214857982, 47.04338297913398]},
#   'address': '116 Legion Way SE, Ste C, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXbIAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXbIAAAAAAAAAA==/',
#   '_etag': '"c20333dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832},
#  {'id': 'SZDFY2cr-M_SsLr9aNEPhA',
#   'alias': 'the-bread-peddler-olympia-4',
#   'name': 'The Bread Peddler',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RIhvY6Yqo66kyNGMi1B4xA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-bread-peddler-olympia-4?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 511,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.04639, 'longitude': -122.90149},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '222 Capitol Way N',
#    'address2': 'Ste 103',
#    'address3': '',
#    'city': 'Olympia',
#    'zip_code': '98501',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['222 Capitol Way N', 'Ste 103', 'Olympia, WA 98501']},
#   'phone': '+13603521175',
#   'display_phone': '(360) 352-1175',
#   'distance': 1075.3247604822054,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d59103fffff',
#   'h3_09': '8928d591027ffff',
#   'h3_10': '8a28d591024ffff',
#   'h3_11': '8b28d591024dfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90149, 47.04639]},
#   'address': '222 Capitol Way N, Ste 103, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-03T09:10:18.886847',
#   '_rid': 'l1clAJGNYXbJAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXbJAAAAAAAAAA==/',
#   '_etag': '"c20334dd-0000-0700-0000-659595080000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704301832}]

# %%
[itm for itm in container.query_items("SELECT * FROM c WHERE c.h3_09 = '8928d5911cbffff'", enable_cross_partition_query=True)]
# Out:
# [{'id': 'RucjyhLr6QiHdlQH1eKaoA',
#   'name': 'Cascadia Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cZjjKcIgnerbWUeZ2M6CNA/o.jpg',
#   'url': 'https://www.yelp.com/biz/cascadia-grill-olympia-3?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 554,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'brasseries', 'title': 'Brasseries'}],
#   'rating': 4.5,
#   'price': '$$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911c9ffff',
#   'h3_11': '8b28d5911c9cfff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.90313455582186, 47.04489344348968]},
#   'address': '200 4th Ave W, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYEAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYEAAAAAAAAAA==/',
#   '_etag': '"ba03a339-0000-0700-0000-6594901f0000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235039},
#  {'id': '8LdL1xJwOE7TXHTD-L0vFg',
#   'name': 'Olympia Oyster House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_ToEC34kLy-PrqIk37cU1A/o.jpg',
#   'url': 'https://www.yelp.com/biz/olympia-oyster-house-olympia-4?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 472,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'price': '$$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911c8ffff',
#   'h3_11': '8b28d5911c8bfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90519, 47.04512]},
#   'address': '320 4th Ave W, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYFAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYFAAAAAAAAAA==/',
#   '_etag': '"ba03a439-0000-0700-0000-6594901f0000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235039},
#  {'id': 'vmFXQJ7MsCnEotwR8qY8PA',
#   'name': 'Chicory',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M7m8c97QtuI9nnLSejARJw/o.jpg',
#   'url': 'https://www.yelp.com/biz/chicory-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 107,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'price': '$$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911c9ffff',
#   'h3_11': '8b28d5911c98fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.903090491891, 47.0451905457797]},
#   'address': '111 Columbia St NW, Olympia, WA, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYGAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYGAAAAAAAAAA==/',
#   '_etag': '"ba03a539-0000-0700-0000-6594901f0000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235039},
#  {'id': '5diQLeEnRaEiI9gYMC-UXg',
#   'name': '1889 Prime Steak House',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/POG3CnM0DJMsB4GS12mO5A/o.jpg',
#   'url': 'https://www.yelp.com/biz/1889-prime-steak-house-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 35,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'price': None,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911caffff',
#   'h3_11': '8b28d5911ca8fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.9056458, 47.04390685157421]},
#   'address': '406 5th Ave SW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYHAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYHAAAAAAAAAA==/',
#   '_etag': '"ba03a639-0000-0700-0000-6594901f0000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235039},
#  {'id': 'HeieXG-dNUTb9aRNP-tPxw',
#   'name': 'Octapas Cafe',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fAHFayHZKkpEPXsp0vuz6w/o.jpg',
#   'url': 'https://www.yelp.com/biz/octapas-cafe-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 201,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'price': '$$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911ca7fff',
#   'h3_11': '8b28d5911ca6fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.9036089, 47.042810716779464]},
#   'address': '610 Water St SW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYJAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYJAAAAAAAAAA==/',
#   '_etag': '"ba03a839-0000-0700-0000-6594901f0000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235039},
#  {'id': '2emCVwaH2CRyK6pMyJwLwg',
#   'name': 'Jerk An Tingz',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KWpVp7ftTqLi1AdxTgGqfQ/o.jpg',
#   'url': 'https://www.yelp.com/biz/jerk-an-tingz-lacey?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 12,
#   'categories': [{'alias': 'popuprestaurants', 'title': 'Pop-Up Restaurants'},
#    {'alias': 'gourmet', 'title': 'Specialty Food'}],
#   'rating': 5.0,
#   'price': None,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911c87fff',
#   'h3_11': '8b28d5911c83fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.903803, 47.044425]},
#   'address': '5700 Lacey Blvd SE, Lacey, WA 98503',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYMAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYMAAAAAAAAAA==/',
#   '_etag': '"ba03ab39-0000-0700-0000-6594901f0000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235039},
#  {'id': '5aSSRpHN_Wjp_DQ9P2lBRw',
#   'name': 'Hotstone Authentic Korean Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jcm9ZCJG3hVwBcW8uvYt5Q/o.jpg',
#   'url': 'https://www.yelp.com/biz/hotstone-authentic-korean-cuisine-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 237,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'price': '$$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911cb7fff',
#   'h3_11': '8b28d5911cb3fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.902461000005, 47.04379482492863]},
#   'address': '119 5th Ave SW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYRAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYRAAAAAAAAAA==/',
#   '_etag': '"ba03b239-0000-0700-0000-6594901f0000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235039},
#  {'id': 'CHxBqgMjinRztDKlaeWe7w',
#   'name': 'Pho Na Saigon Rendezvous',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BmoxEO3NJfrpK7HF5LfRuQ/o.jpg',
#   'url': 'https://www.yelp.com/biz/pho-na-saigon-rendezvous-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 59,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.5,
#   'price': '$$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911cb7fff',
#   'h3_11': '8b28d5911cb3fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90246, 47.04383]},
#   'address': '117 5th Ave SW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYaAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYaAAAAAAAAAA==/',
#   '_etag': '"ba03bc39-0000-0700-0000-659490200000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235040},
#  {'id': '5a-iYCCoP3g51c0IyYDcgQ',
#   'name': 'Nou Thai Street Food',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M1RhcqB6rOISmxzX5RnD4A/o.jpg',
#   'url': 'https://www.yelp.com/biz/nou-thai-street-food-olympia-3?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 81,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'price': None,
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911c87fff',
#   'h3_11': '8b28d5911c81fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.904337, 47.044182]},
#   'address': '415 Water St SW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYcAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYcAAAAAAAAAA==/',
#   '_etag': '"ba03be39-0000-0700-0000-659490200000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235040},
#  {'id': '2s9osEaVRdLAfimJsJZVNA',
#   'name': 'Basilico Ristorante',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iZ5o7ymc44_QdsCDk34wDg/o.jpg',
#   'url': 'https://www.yelp.com/biz/basilico-ristorante-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 239,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'price': '$$$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911cb7fff',
#   'h3_11': '8b28d5911cb2fff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.9019171, 47.0437515]},
#   'address': '507 Capitol Way S, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYfAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYfAAAAAAAAAA==/',
#   '_etag': '"ba03c239-0000-0700-0000-659490200000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235040},
#  {'id': 'w7H6NvUHnGBBxDjvjX-_pw',
#   'name': 'New Moon Cooperative Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/urqmO7SLB4z0pvTBDaq4-A/o.jpg',
#   'url': 'https://www.yelp.com/biz/new-moon-cooperative-cafe-olympia-2?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 566,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 4.0,
#   'price': '$$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911c97fff',
#   'h3_11': '8b28d5911c93fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.9023152, 47.04474713375483]},
#   'address': '113 4th Ave W, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYkAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYkAAAAAAAAAA==/',
#   '_etag': '"ba03c739-0000-0700-0000-659490200000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235040},
#  {'id': 'woB_06lo1TKLNb-T4gR5xw',
#   'name': 'Far East',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0oai762WyWewo7s1PvN3VA/o.jpg',
#   'url': 'https://www.yelp.com/biz/far-east-olympia?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 110,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'price': '$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911c9ffff',
#   'h3_11': '8b28d5911c9dfff',
#   'geometry': {'type': 'Point', 'coordinates': [-122.90389, 47.04492]},
#   'address': '218 4th Ave W, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYlAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYlAAAAAAAAAA==/',
#   '_etag': '"ba03c839-0000-0700-0000-659490200000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235040},
#  {'id': '2ZOVcGNjXxOg8NvOOpK0Vw',
#   'name': 'New Traditions Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AArwUl9_h133commm33u_A/o.jpg',
#   'url': 'https://www.yelp.com/biz/new-traditions-cafe-olympia-2?adjust_creative=ZAyA5LhP0CVLQ3sJwFX2SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZAyA5LhP0CVLQ3sJwFX2SA',
#   'review_count': 84,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'giftshops', 'title': 'Gift Shops'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'price': '$',
#   'h3_07': '8728d5911ffffff',
#   'h3_08': '8828d5911dfffff',
#   'h3_09': '8928d5911cbffff',
#   'h3_10': '8a28d5911c87fff',
#   'h3_11': '8b28d5911c85fff',
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.90423815811, 47.043975915394]},
#   'address': '300 5th Ave SW, Olympia, WA 98501',
#   'retrieval_timestamp': '2024-01-02T14:35:41.990521',
#   '_rid': 'l1clAJGNYXYwAAAAAAAAAA==',
#   '_self': 'dbs/l1clAA==/colls/l1clAJGNYXY=/docs/l1clAJGNYXYwAAAAAAAAAA==/',
#   '_etag': '"ba03d339-0000-0700-0000-659490210000"',
#   '_attachments': 'attachments/',
#   '_ts': 1704235041}]
